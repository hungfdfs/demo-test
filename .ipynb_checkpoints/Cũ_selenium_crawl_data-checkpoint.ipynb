# %%
import time
import json
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

class FacebookCommentCrawler:
    def __init__(self, chrome_driver_path, cookies_file):
        self.chrome_driver_path = chrome_driver_path
        self.cookies_file = cookies_file
        self.driver = None
        self.comments_data = []

    def setup_driver(self):
        """Khởi động trình duyệt Selenium"""
        chrome_options = Options()
        chrome_options.add_argument("--disable-notifications")
        chrome_options.add_argument("--start-maximized")
        chrome_options.add_argument("--disable-blink-features=AutomationControlled")

        service = Service(self.chrome_driver_path)
        self.driver = webdriver.Chrome(service=service, options=chrome_options)

    def load_cookies(self):
        """Đăng nhập vào Facebook bằng cookies"""
        self.driver.get("https://www.facebook.com/")
        time.sleep(3)

        with open(self.cookies_file, "r") as f:
            cookies = json.load(f)
            for cookie in cookies:
                self.driver.add_cookie(cookie)

        self.driver.refresh()
        time.sleep(5)
        print("✅ Đăng nhập thành công!")

    def get_all_post_urls(self, page_id, max_posts=50):
        """Lấy danh sách bài viết từ fanpage"""
        post_urls = set()
        page_url = f"https://www.facebook.com/{page_id}"
        self.driver.get(page_url)
        time.sleep(5)

        last_height = self.driver.execute_script("return document.body.scrollHeight")

        while len(post_urls) < max_posts:
            try:
                posts = self.driver.find_elements(By.XPATH, "//a[contains(@href, '/posts/')]")
                for post in posts:
                    try:
                        url = post.get_attribute("href").split("?")[0]
                        post_urls.add(url)
                    except:
                        continue
                
                self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(3)
                
                new_height = self.driver.execute_script("return document.body.scrollHeight")
                if new_height == last_height:
                    break  # Đã cuộn đến cuối trang, không còn bài mới
                last_height = new_height

            except:
                print("🔄 Lỗi khi lấy bài viết, đang refresh lại...")
                self.driver.refresh()
                time.sleep(5)

            if len(post_urls) >= max_posts:
                break
        
        print(f"🔎 Lấy được {len(post_urls)} bài viết")
        return list(post_urls)

    def expand_all_comments(self):
        """Nhấn nút 'Xem thêm bình luận' để tải toàn bộ bình luận"""
        while True:
            try:
                more_comments_button = self.driver.find_element(By.XPATH, "//span[contains(text(), 'Xem thêm bình luận')]")
                self.driver.execute_script("arguments[0].click();", more_comments_button)
                time.sleep(3)
            except:
                break

    def get_comments_from_post(self, post_url):
        """Lấy tất cả bình luận từ bài viết"""
        self.driver.get(post_url)
        time.sleep(5)

        self.expand_all_comments()  # Tải hết bình luận trước khi lấy dữ liệu

        comments_elements = self.driver.find_elements(By.XPATH, "//div[contains(@aria-label, 'Bình luận')]")

        for comment in comments_elements:
            try:
                commenter_element = comment.find_element(By.XPATH, ".//a")
                commenter_name = commenter_element.text
                username = commenter_element.get_attribute("href").split("?")[0]

                comment_text_element = comment.find_elements(By.XPATH, ".//div[2]//span")
                comment_text = " ".join([c.text for c in comment_text_element if c.text.strip()])

                try:
                    reactions_element = comment.find_element(By.XPATH, ".//span[contains(@aria-label, 'lượt thích')]")
                    reactions_count = int(reactions_element.text) if reactions_element.text.isdigit() else 0
                except:
                    reactions_count = 0

                comment_date = "Không xác định"

                self.comments_data.append({
                    'username': username,
                    'commenter_name': commenter_name,
                    'post_url': post_url,
                    'comment_date': comment_date,
                    'comment_text': comment_text,
                    'comment_reactions': reactions_count
                })
            except:
                continue

        print(f"💬 Thu thập {len(comments_elements)} bình luận từ {post_url}")
    
    def crawl_fanpage(self, page_id, max_posts=50):
        """Crawl tất cả bình luận từ fanpage"""
        self.setup_driver()
        self.load_cookies()

        post_urls = self.get_all_post_urls(page_id, max_posts)

        for post_url in post_urls:
            self.get_comments_from_post(post_url)
            time.sleep(2)

        output_file = f"facebook_comments_{page_id}.xlsx"
        df = pd.DataFrame(self.comments_data)
        df.to_excel(output_file, index=False)

        print(f"✅ Crawl hoàn tất! Dữ liệu đã lưu vào {output_file}")
        self.driver.quit()

if __name__ == "__main__":
    chrome_driver_path = "C:/Users/THINK/Desktop/NLP Vnua/Selenium/chromedriver-win64/chromedriver.exe"
    cookies_file = "cookies.json"
    page_id = "bistar.ecopark"

    crawler = FacebookCommentCrawler(chrome_driver_path, cookies_file)
    crawler.crawl_fanpage(page_id, max_posts=50)
# Out:
# ✅ Đăng nhập thành công!
# 🔎 Lấy được 50 bài viết
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0G9o4zYNankoPkT65zi5a5wDCC93ahLdBgki164LHAdPeXu6VxBqxvzLj8aVJHif8l
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02WQjU7vKtyNyhpttr8x4uBYHgjtsoW29vrDQSwyq2T8gCPY8r7tXHUWTrQfzFX1Bal
# 💬 Thu thập 6 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0333N1avMXgwMHe13GWaP5ATQ7LCnP6gQEcoMVvN7A1NttQdKd2dUiFepK56nYdcgel
# 💬 Thu thập 11 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid09nfX7XNLuAXw7Dwmq4pquvbbgBiYFR7dHJTN9y5852Qo3q5qMfTcXPuHeahZ2UTEl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02cp3hezRdRtQWjcwnfkNDhDerzFQ81qvyYCpBB1A1FHZrDwL6hqfmhiLhou6vH373l
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0R1C5ZHP743kiXZMcWRqaneZhsK6r3KggELN1UrDRh8ogZchFvfLVjukNAHLZmaaBl
# 💬 Thu thập 3 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0253EcmwPUHEb7FWtJLW58SZdwcc1pc52R965CLDtfh5y3Utx2Zuk3MJGvmd35o9gol
# 💬 Thu thập 3 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02bt6b7dwryTVYRfhvGWqSSanvgDm64hj46PGtWfKbgaCmDDroL1UiRkYY5KyGNoYvl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid054f3f2joctFSJnrhxtHT5ZXhK5SWiAGE94Y4euPqhW5jBbaNyjV69JN4KBY2rNqDl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid032EwytnbK8ZCKCAfKdgU4J9cqtJExWj2mjBbMfegFTkMAMmo1JLjx1UgodctSK17fl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0CSS46t323QWJhwG1qJkCzeBK87UJB82nduCwqddxbw1SSmfZ2arvQFV5zmV5fFeMl
# 💬 Thu thập 1 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02cYyaq2GjK9rrVk9BK9x6aKU9JtVY4UcsvFFzoxCApmH2s8KGSvwjgVKsmdUcVptYl
# 💬 Thu thập 3 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02ouWhhsgdYJW7A1Jae6jaQi7uVDo46tojCHXFwdgNgde1xd5iZWcotqJs5kqK4HpDl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02n4GXnrXwt6S5WxHvg9ELztqqokYKiC1aoXduKWzDtaVUPhGcC5BtPpgPibdZofVcl
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02VbSmNAXUzDTD1EHXejPtbDY666WNB3b7Kkjwz3Qdb1zMHhA62WtMn3HsbsWpgg62l
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0hp1134WKqoEnstNPAMeA5LzDT8k581KH8nRmDj8oiFb6P7mdwJTxAPHPRMzAmrvHl
# 💬 Thu thập 3 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0jQij38Gz2YMvqZwsnh9iq2qeQmDguSBA45o8TM9HJmNC29e5cspT4s2MbH4uZTVJl
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid08EZpJKiGzgRY8vtGNgm4vcUyGQvRXaQJMLYXpNqNAKhpNjECt2BxGGRkPRKFtCeal
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid035auVkj13v5GcpZyWVwv92vQjr18DaBbWYpkxNLt2ZiGLEj48gQqfh4BQ8wKhEx5Vl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid026XWdC3dRh97KWXtcertsFE6rGh8g2EgqYJdwkWXJuBzoeKg5ja7kQbSBnAPptRFkl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0iFLZHKF94d2KdxP4pDadifCoferedgqLV6ydNozrJF82h36MRji2p71rroCSCkZRl
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02bLkhghyeNPuS9aFMmSyA5vFQjYmRY2GeeUMXuNP7Mwc8PQ5471NkSraqqwdHQy7Nl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid04yrLp7Ximhv9YoHXAnkkKXvP7iLNsTyJ6Bn8yfQatpVXJEXJeapd4zBXqun2mYz6l
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0KRvtTPND5hP32Api5jUUUUn5z7bNMw5sErgf5L7TGJoGQ2CDtke2qfR84ZYW4e2tl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid04NU3MDMe9Bf7fPitZYsVueHQiehqoEcCBH6NSiYGqWdccjbv1DsJMcbzSfzRmhoil
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02zNq8v9QS3TzNG73MRkYW7j6UtRH8ZwpJX13o1Dj8qZRavShvg8WG7qTJQrVpNQKhl
# 💬 Thu thập 6 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02z7S1wZzD9JWMBW1Cte8atDBfUsh222bQxa8vENDXSaa6M8sxPyQW4a2AJCaqXWqil
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02u8a6RWiKc6rLSyPzDWCyF3EU7EMsVBd67133nbwCTVofa2Cu9FWKJ5r8ddz2gZBfl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0yureqJtGAqyFurTvwLQCdrPm7XH379TmPw5NATDSTmX1YN96798HEhwCHiGKGLCpl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid029ayhgciJ8dAzyoD9uegUtHooEojXrm1TG6wysrkVf3qkNG2SotcDstAx3qYX1KxRl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0uyAsEvUCALKeVYgxfkAsjuGcFbSyRiqiSA44YQ8JMKpXVcf3vzZ3f7zMdiBCQEWGl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0efAdbQQVDGL5Le1YkCAbc2puo9QxVVzEBNGZKM49Qmce238YBSFbFx3EucPSYMrl
# 💬 Thu thập 1 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02Dm6ZvhKYVGfDFdvyfDQAcf2i29PWKmPN9NrCH6i7RfZUKKPTzTtR7b62sVCvDmVel
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02viR9MxSnNEeoPQLN8g9FBbDuv73UK227tJSVeP7KcUUTUop9EKGvPFLcfig3LdnCl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02uKvrEbCt9zHZrVxVL9CYSPidiD4icRCAKvYDQziMKFwfaSTFYyrhJZzeUmyFmWanl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02sWm2bRPv8rEfQRTXo6rRW2gWbGS37AEKZJJFeGoaub4ugXN4CJXtApJWbwRadoYKl
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0BoxSFBxHy6QpaFqB8AgUeQEbdncqat1AUWmFdKEN88bwtcc7vxi6F8ieKHJWMC4tl
# 💬 Thu thập 1 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0xCoYdVLg8vZ5JmR5HAGJfqKQrcuAWi1cWGSuRdcND3qgn6KD7t5Fvma8NArJAr8dl
# 💬 Thu thập 2 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0228qKvfE6aCx5osty7WX3AAngB2oN1LZauUVWtKe8Uv1XVYBDa2nxosiwVoMvwL51l
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0WPCpo527ZpFm7MRvfSirZrDrzdG9ca8J1LG6G5wyd9z8Mz14osShV4eyqprLcwanl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02dJ7b35Pi22zTTsL52UiJDf7z49My7g8wLjvuh7Ejrx54fdaLhPZRkQ8U4paBUUHXl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid033inen5pAq8BX3pmkWuKzCzy8tUSfP5uxoo3gEbBJmJ7dmgM5TQKKJV3dQ7Tmxncjl
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid031LJuP6owf2iqoPLEg6yi4JscJnmA83Twmbc9ttYP6T2hbLRNHUQ125i2DTyjiE6ql
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0A4pxLHRtTcrM614D5ghijWYqd1JkEc5LEaLaEjcJX2PBsR8KmYu5BWH5eRCapkksl
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0jBHePS5ogDF6NRipoymjUAEhhP8ZrFji8AUckxUyX2yNTAPofF3dSEWzYiMwdeGJl
# 💬 Thu thập 7 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02P5FUiKsx3NuMrPTKTkDP1TEtp3h6VJgbL6fib9ckJJDsKUbg7AE3hJs9Y5X8sCj6l
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02x6o777vueST44orari28k16S3fzyTYmeDHfLagSVWz83fwg5RTV49qo1NKESpyuql
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid0Eo47zRD5S6y6cjF41tynb3Wn7gWihR9WJSpZcv4L86v8vWQHzaFaRAuZEfhv7N3Ll
# 💬 Thu thập 5 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid07XHVbiRU58WJgCdB9vjjyeswGDSkWwyeEYBSvqKiRtjV9Kyf7Eibr1EcrbYhKj8Ul
# 💬 Thu thập 4 bình luận từ https://www.facebook.com/bistar.ecopark/posts/pfbid02kf8ENGmQ6wzZ6S4WJ2WRAV6es3qGGBG3Rmqta7utkrDfAhqHRHbQcfUxdKv5rRjVl
# ✅ Crawl hoàn tất! Dữ liệu đã lưu vào facebook_comments_bistar.ecopark.xlsx
